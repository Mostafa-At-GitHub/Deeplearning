# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection= '3d')
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
z = x*y
ax.plot_wireframe(x, y, z)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c='r', marker='o')
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')

# %% [markdown]
# # Multiple datases scatter plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c='r', marker='o')

xs = np.random.rand(100)
ys = np.random.randn(100)
zs = np.random.rand(100)
print(zs)
ax.scatter(xs, ys, zs, c='b', marker='^')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
plt.show()
# Out:
# [ 0.7150721   0.16026665  0.91747893  0.99290594  0.26432228  0.85056111
#   0.42947269  0.08091199  0.57086692  0.42892143  0.70171547  0.5882942
#   0.05985158  0.03153594  0.63185637  0.68211764  0.84053851  0.65053057
#   0.02197927  0.62420823  0.69554025  0.23212533  0.75313175  0.3884184
#   0.63809298  0.72114917  0.84375606  0.92364847  0.62783146  0.52285648
#   0.32226603  0.24660323  0.4531916   0.54149694  0.28023685  0.0752319
#   0.5298495   0.86124733  0.35959418  0.72736343  0.99786852  0.01773167
#   0.42495758  0.6477373   0.16991772  0.35383824  0.19570241  0.18651564
#   0.21440935  0.01767523  0.37094774  0.39927048  0.71905757  0.04889112
#   0.25303909  0.15537529  0.04501013  0.76866691  0.77037524  0.12048275
#   0.32015657  0.91017001  0.27470702  0.57456687  0.30956765  0.7534352
#   0.80116508  0.33706465  0.77140133  0.05024564  0.83919541  0.07006876
#   0.06200724  0.30316433  0.87235565  0.97693875  0.5824196   0.18715381
# ...

# %% [markdown]
# # meshgrid(Numpy)
# return a coordinate matrices from coordinate vectors
# parameters:
# ```
#     array
#     idexing {'xy', 'ij'}
#     sparse: bool(optional) for conserving memory
#     copy: bool(optional)
# ```
# # bivariate_normal
# bivariate normal distribution for equal shape x and y
# sigmax, sigmay, mux, muy, sigmaxy

# %%
def makeTestData(delta = 0.05):
    from matplotlib.mlab import bivariate_normal
    x = y = np.arange(-3.0, 3.0, delta)
    X, Y=np.meshgrid(x,y)
    print(X.shape)
    Z1 = bivariate_normal(X, Y, 1.0, 1.0,0.0,0.0)
    Z2 = bivariate_normal(X, Y, 1.5, 0.5,1,1)
    Z = Z2 - Z1
    X= X*10
    Y= Y*10
    Z= Z*500
    return X, Y, Z
    
makeTestData()
# Out:
# (120, 120)
# (array([[-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#         [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#         [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#         ...,
#         [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#         [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#         [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5]]),
#  array([[-30. , -30. , -30. , ..., -30. , -30. , -30. ],
#         [-29.5, -29.5, -29.5, ..., -29.5, -29.5, -29.5],
#         [-29. , -29. , -29. , ..., -29. , -29. , -29. ],
#         ...,
#         [ 28.5,  28.5,  28.5, ...,  28.5,  28.5,  28.5],
#         [ 29. ,  29. ,  29. , ...,  29. ,  29. ,  29. ],
#         [ 29.5,  29.5,  29.5, ...,  29.5,  29.5,  29.5]]),
#  array([[-0.00982064, -0.0113957 , -0.01319036, ..., -0.01522953,
#          -0.01319036, -0.0113957 ],
#         [-0.0113957 , -0.01322338, -0.01530587, ..., -0.01767209,
#          -0.01530587, -0.01322338],
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y, z = makeTestData()
ax.plot_wireframe(x,y,z,rstride=1, cstride=11)
# Out:
# (120, 120)
